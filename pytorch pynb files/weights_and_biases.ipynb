# %% [markdown]
# <a href="https://colab.research.google.com/github/khanma1962/Fire-Classification-and-Detection/blob/main/weights_and_biases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fire Classification

# %% [markdown]
# ###Hyperparameter Tuning with Weights and Biases
#
# https://wandb.ai/site/articles/running-hyperparameter-sweeps-to-pick-the-best-model-using-w-b
#
# https://colab.research.google.com/drive/1K8EQ_ENXEw1uDykCYXo4X7XZgYE8zsVs#scrollTo=r4VjKui20N3j

# %%
# copying data from drive to colab Pro for faster simulation

# !mkdir clf
# !mkdir clf/data
# !mkdir clf/data/train
# !mkdir clf/data/test
# !cp -r /content/drive/MyDrive/Data_Science/projects/Fire_Detection_System/fire_classification/data/train/* clf/data/train/
# !cp -r /content/drive/MyDrive/Data_Science/projects/Fire_Detection_System/fire_classification/data/test/* clf/data/test/
# !cp -r /content/drive/MyDrive/Data_Science/projects/Fire_Detection_System/fire_classification/data/*.csv clf/data/

# %%
# !nvidia-smi
# Out:
# Wed Jun 23 20:25:31 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory

print(virtual_memory().total / 1e9,  'GB')
# Out:
# 27.339640832 GB

# %%
# !pip install wandb -qqq
# Out:
#      |████████████████████████████████| 1.8MB 4.3MB/s
#      |████████████████████████████████| 174kB 53.8MB/s
#      |████████████████████████████████| 133kB 53.6MB/s
#      |████████████████████████████████| 102kB 14.6MB/s
#      |████████████████████████████████| 71kB 11.5MB/s
#   Building wheel for pathtools (setup.py) ... done
#   Building wheel for subprocess32 (setup.py) ... done

# %%
# calling all libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader 
import torch.nn.functional as F
from torchvision import  models, transforms
from torchvision.utils import make_grid
import torch.optim as optim

import os, math
from PIL import Image
from IPython.display import display

# remove run/ dir
# !rm -rf runs/  # remove previous runs
# from torch.utils.tensorboard import SummaryWriter

# import albumentations as alb
# from albumentations.pytorch import ToTensor

import time
import warnings
warnings.filterwarnings('ignore')

import wandb

torch.manual_seed(42)

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
torch.__version__
# Out:
# '1.9.0+cu102'

# %% [markdown]
# ### Image files directory tree
#
#
# <pre>.
# └──   fire_classification
#         ├── test
#         │       ├── Fire_0.jpg
#         │       ├── Fire_1.jpg
#         │       └── ... (100 files)
#         │       ├── No_Fire_0.jpg
#         │       ├── No_Fire.jpg
#         │       └── ... (100 files)
#         │
#         └── train
#                 ├── Fire_0.jpg
#                 ├── Fire_1.jpg
#                 └── ... (900 files)
#                 ├── No_Fire_0.jpg
#                 ├── No_Fire1.jpg
#                 └── ... (900 files)</pre>

# %%
# root dir and naming

# root_dir = '/content/drive/MyDrive/Data_Science/projects/Fire_Detection_System/fire_classification/'
root_dir = 'clf'
# print(os.path.join(root_dir))
dir_list = ['train', 'test']

train_labels = pd.read_csv(root_dir + '/data/train.csv')
test_labels  = pd.read_csv(root_dir + '/data/test.csv')
print(train_labels.head())
print('*'*50)
train_path = root_dir + '/data/' + dir_list[0]
test_path  = root_dir + '/data/' + dir_list[1]
has_fire = {1 : 'Fire', 0 : 'No_Fire'}

#check if dataset is balanced
print(train_labels['has_Fire'].value_counts())
print('*'*50)
#checking the number of files in each directories
for (path, dir, files) in os.walk(os.path.join(root_dir + '/data')):
    print(f"{path} has {len(os.listdir(path))} number of files")
# Out:
#      Image_no  has_Fire
# 0  Fire_0.jpg         1
# 1  Fire_1.jpg         1
# 2  Fire_2.jpg         1
# 3  Fire_3.jpg         1
# 4  Fire_4.jpg         1
# **************************************************
# 0    999
# 1    985
# Name: has_Fire, dtype: int64
# **************************************************
# clf/data has 4 number of files
# clf/data/train has 1984 number of files
# clf/data/test has 170 number of files

# %%
train_labels.head()
# Out:
#      Image_no  has_Fire
# 0  Fire_0.jpg         1
# 1  Fire_1.jpg         1
# 2  Fire_2.jpg         1
# 3  Fire_3.jpg         1
# 4  Fire_4.jpg         1

# %%
len(train_labels)
# Out:
# 1984

# %%
# see the first image

x = np.random.randint(len(train_labels))

fire_jpg = os.listdir(os.path.join(root_dir, 'data/' + 'train/'))[x]
fire_loc = os.path.join(root_dir, 'data/' + 'train/') +'/' + fire_jpg
fire_img = imread(fire_loc)
fire_lbl = has_fire[train_labels[train_labels['Image_no'] == fire_jpg]['has_Fire'].values[0]]
plt.imshow(fire_img)
print(f'The type is {fire_lbl} and shape of the image is  {fire_img.shape}')
# Out:
# The type is No_Fire and shape of the image is  (195, 258, 3)

# %% [markdown]
# ### Dataset and Dataloader

# %%
# Weight and Bias config
#https://docs.wandb.ai/guides/sweeps/configuration

sweep_config = {
    'method' : 'random',
    'metric' : {'name' : 'loss', 'goal'   : 'minimize'}}

parameters_dict = {
        'optimizer' : { 'values' : ['adam', 'sgd']},
        'mid_layer_size' : {'values' : [256, 512, 1024]},
        'dropout' : {'values' : [0.4, 0.5, 0.6] }}

sweep_config['parameters'] = parameters_dict
                    
                    
parameters_dict.update({
        'epochs' : {'value' : 10},
        'learning_rate': {'distribution' : 'uniform',   'min' : 0.0, 'max' : 0.1},
        'batch_size' : {'distribution': 'q_log_uniform', 'q' : 1, 'min': math.log(32), 'max': math.log(256)} # https://stackoverflow.com/questions/53789280/qloguniform-search-space-setting-issue-in-hyperopt             
        })

sweep_id = wandb.sweep(sweep_config, project= 'pytorch_hp_tuning ')

import pprint
pprint.pprint(sweep_config)
# Out:
# wandb: WARNING Malformed sweep config detected! This may cause your sweep to behave in unexpected ways.
# wandb: WARNING To avoid this, please fix the sweep config schema violations below:
# wandb: WARNING   Violation 1. {'max': 0.1, 'min': 0, 'distribution': 'uniform'} is not valid under any of the given schemas
# Create sweep with ID: a15hf3ib
# Sweep URL: https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib
# {'method': 'random',
#  'metric': {'goal': 'minimize', 'name': 'loss'},
#  'parameters': {'batch_size': {'distribution': 'q_log_uniform',
#                                'max': 5.545177444479562,
#                                'min': 3.4657359027997265,
#                                'q': 1},
#                 'dropout': {'values': [0.4, 0.5, 0.6]},
#                 'epochs': {'value': 10},
#                 'learning_rate': {'distribution': 'uniform',
#                                   'max': 0.1,
#                                   'min': 0.0},
#                 'mid_layer_size': {'values': [256, 512, 1024]},
#                 'optimizer': {'values': ['adam', 'sgd']}}}

# %%
# Creating class Dataset

class FireDataset(torch.utils.data.Dataset):
    "Inhereting Dataset from torch and adding stuff"
    def __init__(self, data, path, transforms=None):
        super().__init__()
        'initialize first'
        # print(list_IDs, labels)
        self.path = path
        self.data = data.values
        self.transforms = transforms


    def __getitem__(self, index):
        'generate one sampe of data'
        #select sample
        img_name, label = self.data[index]
        img_path = os.path.join(self.path, img_name)
        image = Image.open(img_path)
        image = image.convert('RGB') # https://stackoverflow.com/questions/11064786/get-pixels-rgb-using-pil
        
        if self.transforms is not None:
            image = self.transforms(image)

        return image, label

    
    def __len__(self):
        'indicate total number of samples'
        return len(self.data)

# %%
# train function

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def train(config = None):
    #initliaze a new  run
    with wandb.init(config = config):

        config = wandb.config

        loader = build_dataset(config.batch_size, train_labels, train_path )
        network = build_network(config.mid_layer_size, config.dropout)
        optimizer = build_optimizer(network, config.optimizer, config.learning_rate)

        for epoch in range(config.epochs):
            avg_loss = train_epoch(network, loader, optimizer)
            wandb.log({"loss": avg_loss, "epoch": epoch})

def build_dataset(batch_size, train_labels, train_path ):
    transform = transforms.Compose([
            transforms.Resize(224),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize( (.1307,), (0.3081,))
                    # mean = [0.485, 0.456, 0.406],
                    # std = [0.229, 0.224, 0.225])                       
            ])
    
    training_set = FireDataset(train_labels, train_path, transforms=transform)
    training_generator = DataLoader(training_set, batch_size= batch_size, shuffle=True)
 
    return training_generator


def build_network(mid_layer_size , dropout ):
    #Pre-trained model
    resnet50_model = models.resnet50(pretrained= True)

    # Freeze feature parameters
    for param in resnet50_model.parameters():
        param.requires_grad = False

    # add a new fc of binary class instead of 1000 classes
    resnet50_model.fc = nn.Sequential(
                                nn.Linear(2048, mid_layer_size),
                                nn.ReLU(),
                                nn.Dropout(dropout),
                                nn.Linear(mid_layer_size, 2),
                                # nn.LogSoftmax(dim=1)).to(device)
                                nn.Sigmoid())
    return resnet50_model.to(device)


def build_optimizer(resnet50_model, optimizer, learning_rate):
    if optimizer == 'sgd':
        optimizer = optim.SGD(resnet50_model.parameters(), 
                              lr= learning_rate, momentum = 0.9)
    elif optimizer == 'adam':
        optimizer = optim.Adam(resnet50_model.parameters(),
                               lr = learning_rate)
    return optimizer


def train_epoch(resnet50_model, training_generator, optimizer):
    cumm_loss = 0
    for _ , (data, target) in enumerate(training_generator):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()

        # Forward pass
        # loss = F.nll_loss(resnet50_model(data), target)
        lss = nn.CrossEntropyLoss()
        loss = lss(resnet50_model(data), target)
        cumm_loss += loss.item()

        #backward pass and weight update
        loss.backward()
        optimizer.step()

        wandb.log({"batch loss" : loss.item()})
    
    return cumm_loss / len(training_generator)

# %%
# launch an agent

wandb.agent(sweep_id, train, count= 100) #5 )
# Out:
# wandb: Agent Starting Run: wu9wmb3r with config:
# wandb: 	batch_size: 37
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.07838967676351048
# wandb: 	mid_layer_size: 1024
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">lucky-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/wu9wmb3r" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/wu9wmb3r</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_204731-wu9wmb3r</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1027<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_204731-wu9wmb3r/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_204731-wu9wmb3r/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.79152</td></tr><tr><td>_runtime</td><td>152</td></tr><tr><td>_timestamp</td><td>1624481403</td></tr><tr><td>_step</td><td>549</td></tr><tr><td>loss</td><td>0.80961</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▂▁▂▅▆▆▂▇▄▆▃▆▃▄▇▅▄▇▆▂▆▅▄▆▆▅▃▄▅▆▆▂▄█▃▄▄▄▅▆</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁█████████</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">lucky-sweep-1</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/wu9wmb3r" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/wu9wmb3r</a><br/>
# wandb: Agent Starting Run: 9nxblvch with config:
# wandb: 	batch_size: 39
# wandb: 	dropout: 0.6
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.07443100926252738
# wandb: 	mid_layer_size: 256
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">fresh-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/9nxblvch" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/9nxblvch</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_205009-9nxblvch</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1076<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_205009-9nxblvch/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_205009-9nxblvch/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.81326</td></tr><tr><td>_runtime</td><td>149</td></tr><tr><td>_timestamp</td><td>1624481558</td></tr><tr><td>_step</td><td>519</td></tr><tr><td>loss</td><td>0.81678</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▇▆▂▄▂▂▇▂▄▅▅▃▄▅▄▇▁▄▆▇▂▁▇▇▃█▆▆▅▄▅▄▆▄▄▄▂▃▂▇</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁█████████</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">fresh-sweep-2</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/9nxblvch" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/9nxblvch</a><br/>
# wandb: Agent Starting Run: gnhpfswv with config:
# wandb: 	batch_size: 107
# wandb: 	dropout: 0.6
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.011367452436891613
# wandb: 	mid_layer_size: 1024
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">balmy-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/gnhpfswv" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/gnhpfswv</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_205246-gnhpfswv</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1123<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_205246-gnhpfswv/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_205246-gnhpfswv/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.86499</td></tr><tr><td>_runtime</td><td>148</td></tr><tr><td>_timestamp</td><td>1624481714</td></tr><tr><td>_step</td><td>199</td></tr><tr><td>loss</td><td>0.81107</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▁▇▆▇▇▅▅▆▇▇▇▆▆▅▇█▅▇▇▆▇▆▅▆▆▆▆▇▇▆▆▆█▅▅▆▇▅▇▇</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁▇██▇█▇█▇█</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">balmy-sweep-3</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/gnhpfswv" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/gnhpfswv</a><br/>
# wandb: Agent Starting Run: bqxk7lsf with config:
# wandb: 	batch_size: 156
# wandb: 	dropout: 0.6
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.03477453024370073
# wandb: 	mid_layer_size: 256
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">electric-sweep-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/bqxk7lsf" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/bqxk7lsf</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_205520-bqxk7lsf</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1172<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_205520-bqxk7lsf/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_205520-bqxk7lsf/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.32625</td></tr><tr><td>_runtime</td><td>146</td></tr><tr><td>_timestamp</td><td>1624481866</td></tr><tr><td>_step</td><td>139</td></tr><tr><td>loss</td><td>0.32928</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>██▇▇▅▄▄▃▂▂▂▂▁▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▂▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">electric-sweep-4</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/bqxk7lsf" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/bqxk7lsf</a><br/>
# wandb: Agent Starting Run: eshtomla with config:
# wandb: 	batch_size: 41
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 1.41704419950206e-05
# wandb: 	mid_layer_size: 1024
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">brisk-sweep-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/eshtomla" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/eshtomla</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_205752-eshtomla</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1217<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_205752-eshtomla/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_205752-eshtomla/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.6881</td></tr><tr><td>_runtime</td><td>149</td></tr><tr><td>_timestamp</td><td>1624482021</td></tr><tr><td>_step</td><td>499</td></tr><tr><td>loss</td><td>0.68591</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▇▆▅▇▄▅▄▅▄▅▄▇▅█▅▃▇▅▅▅▂█▃▄▃▁▄▅▆▅▂▄▄▃▂▇▄▄▁▄</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>██▇▅▆▅▄▄▄▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">brisk-sweep-5</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/eshtomla" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/eshtomla</a><br/>
# wandb: Agent Starting Run: qvkav61m with config:
# wandb: 	batch_size: 91
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0073090108346824945
# wandb: 	mid_layer_size: 512
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">spring-sweep-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/qvkav61m" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/qvkav61m</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_210028-qvkav61m</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1284<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_210028-qvkav61m/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_210028-qvkav61m/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.82011</td></tr><tr><td>_runtime</td><td>146</td></tr><tr><td>_timestamp</td><td>1624482174</td></tr><tr><td>_step</td><td>229</td></tr><tr><td>loss</td><td>0.80983</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▁▆█▇▆▇▇▆▇▆▆▆▇▇▅▆▆█▆▅▄▆▇▇▆▆▆█▅▇▆▅▅▇▆▅▆▅▇▆</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁██▇██▇███</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">spring-sweep-6</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/qvkav61m" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/qvkav61m</a><br/>
# wandb: Agent Starting Run: hg1vcitr with config:
# wandb: 	batch_size: 60
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.005740898915490933
# wandb: 	mid_layer_size: 1024
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">bright-sweep-7</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/hg1vcitr" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/hg1vcitr</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_210300-hg1vcitr</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1355<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_210300-hg1vcitr/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_210300-hg1vcitr/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.3296</td></tr><tr><td>_runtime</td><td>148</td></tr><tr><td>_timestamp</td><td>1624482328</td></tr><tr><td>_step</td><td>349</td></tr><tr><td>loss</td><td>0.34216</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>██▇▇▆▅▄▃▄▃▂▂▂▂▂▂▂▁▂▂▁▂▁▁▂▁▁▂▁▂▁▁▁▁▁▁▁▁▂▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▃▂▂▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">bright-sweep-7</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/hg1vcitr" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/hg1vcitr</a><br/>
# wandb: Agent Starting Run: oq7icvte with config:
# wandb: 	batch_size: 225
# wandb: 	dropout: 0.4
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.07067399190697803
# wandb: 	mid_layer_size: 256
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">serene-sweep-8</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/oq7icvte" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/oq7icvte</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_210534-oq7icvte</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1426<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_210534-oq7icvte/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_210534-oq7icvte/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.34294</td></tr><tr><td>_runtime</td><td>148</td></tr><tr><td>_timestamp</td><td>1624482482</td></tr><tr><td>_step</td><td>99</td></tr><tr><td>loss</td><td>0.32761</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>██▇▇▅▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">serene-sweep-8</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/oq7icvte" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/oq7icvte</a><br/>
# wandb: Agent Starting Run: yc5bp1xa with config:
# wandb: 	batch_size: 109
# wandb: 	dropout: 0.4
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.07976651660083045
# wandb: 	mid_layer_size: 1024
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">electric-sweep-9</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/yc5bp1xa" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/yc5bp1xa</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_210807-yc5bp1xa</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1471<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_210807-yc5bp1xa/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_210807-yc5bp1xa/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.99508</td></tr><tr><td>_runtime</td><td>147</td></tr><tr><td>_timestamp</td><td>1624482634</td></tr><tr><td>_step</td><td>199</td></tr><tr><td>loss</td><td>0.82398</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▄▁▄▄▆▆▃▅▅▅▅▄▅▄▇▄▄▄▅▅▅▄▄▅▅▄▅▅▄▄▇▄▅▅▄▄▆▅▅█</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁▇▇▇▇▇██▇█</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">electric-sweep-9</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/yc5bp1xa" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/yc5bp1xa</a><br/>
# wandb: Agent Starting Run: uka8y30t with config:
# wandb: 	batch_size: 148
# wandb: 	dropout: 0.4
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.05210926220289678
# wandb: 	mid_layer_size: 512
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">divine-sweep-10</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/uka8y30t" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/uka8y30t</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_211040-uka8y30t</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1544<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_211040-uka8y30t/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_211040-uka8y30t/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.81326</td></tr><tr><td>_runtime</td><td>146</td></tr><tr><td>_timestamp</td><td>1624482786</td></tr><tr><td>_step</td><td>149</td></tr><tr><td>loss</td><td>0.81664</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▆▇▅▃▇▅▅▄▆▅▅▄▅▄▅▄▄▃▆▃▇▁▄█▄▆▁▅▅▅▃▅▅▅▅▄▅▄▂▄</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁█▇▆▇▆▇▆▇▇</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">divine-sweep-10</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/uka8y30t" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/uka8y30t</a><br/>
# wandb: Agent Starting Run: xcts8j4j with config:
# wandb: 	batch_size: 238
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0011249260506797532
# wandb: 	mid_layer_size: 512
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">cool-sweep-11</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/xcts8j4j" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/xcts8j4j</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_211312-xcts8j4j</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1619<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_211312-xcts8j4j/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_211312-xcts8j4j/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.62611</td></tr><tr><td>_runtime</td><td>153</td></tr><tr><td>_timestamp</td><td>1624482945</td></tr><tr><td>_step</td><td>99</td></tr><tr><td>loss</td><td>0.62914</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>██▇▇▇█▇▇▇▇▆▆▆▆▅▅▅▅▅▅▄▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▂▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>██▇▆▅▄▄▃▂▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">cool-sweep-11</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/xcts8j4j" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/xcts8j4j</a><br/>
# wandb: Agent Starting Run: e4d8mqmr with config:
# wandb: 	batch_size: 98
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.042327987543298806
# wandb: 	mid_layer_size: 512
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">eager-sweep-12</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/e4d8mqmr" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/e4d8mqmr</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_211550-e4d8mqmr</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1694<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_211550-e4d8mqmr/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_211550-e4d8mqmr/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.85493</td></tr><tr><td>_runtime</td><td>147</td></tr><tr><td>_timestamp</td><td>1624483097</td></tr><tr><td>_step</td><td>219</td></tr><tr><td>loss</td><td>0.81136</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▇▄▁▆▄▆▃▆▃▄▅▄▂▇▃▄▄▆▅▃▄▆█▆▅▄▄▄▅▄▆▂▅▇▆▂▅▅▂▆</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▄▁▅▅▅█▃▇▅▆</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">eager-sweep-12</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/e4d8mqmr" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/e4d8mqmr</a><br/>
# wandb: Agent Starting Run: geimwvjb with config:
# wandb: 	batch_size: 50
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.09513472596591838
# wandb: 	mid_layer_size: 1024
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">elated-sweep-13</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/geimwvjb" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/geimwvjb</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_211823-geimwvjb</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1767<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_211823-geimwvjb/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_211823-geimwvjb/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.72503</td></tr><tr><td>_runtime</td><td>150</td></tr><tr><td>_timestamp</td><td>1624483253</td></tr><tr><td>_step</td><td>409</td></tr><tr><td>loss</td><td>0.80906</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▃▂▅▄▂▅▅▄█▄▃▄▁▅▃▁▅▂▅▄▄▃▄▅▅▇▅▂▇▃▃▃▅▃▅▂▆▃█▂</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁▄▂▃▃█▇▅▄▃</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">elated-sweep-13</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/geimwvjb" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/geimwvjb</a><br/>
# wandb: Agent Starting Run: j54tetil with config:
# wandb: 	batch_size: 80
# wandb: 	dropout: 0.6
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.07119905054467084
# wandb: 	mid_layer_size: 256
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">desert-sweep-14</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/j54tetil" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/j54tetil</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_212100-j54tetil</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1842<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_212100-j54tetil/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_212100-j54tetil/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.81326</td></tr><tr><td>_runtime</td><td>149</td></tr><tr><td>_timestamp</td><td>1624483409</td></tr><tr><td>_step</td><td>259</td></tr><tr><td>loss</td><td>0.80945</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▄▅▄▅▄▄▁▆▃▄▅▇▄▇▇▅▄▃▃▅▄▃▁▄▄▅▆▇▇▇▂█▆▇▆▅▆▄▆▇</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁█▆▅▅▆▆▅▆▅</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">desert-sweep-14</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/j54tetil" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/j54tetil</a><br/>
# wandb: Agent Starting Run: 0hq7d047 with config:
# wandb: 	batch_size: 35
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.07681391549757327
# wandb: 	mid_layer_size: 256
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">restful-sweep-15</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/0hq7d047" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/0hq7d047</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_212335-0hq7d047</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1915<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_212335-0hq7d047/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_212335-0hq7d047/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.85493</td></tr><tr><td>_runtime</td><td>151</td></tr><tr><td>_timestamp</td><td>1624483566</td></tr><tr><td>_step</td><td>579</td></tr><tr><td>loss</td><td>0.80998</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▄▆▄▇▂▂▁▄▃▅▃▄▃▁▂█▅▄▃▃▁▄▅▄▃█▇▂▅▄▄▅▅▇▁▄▆▄▂▅</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁▇▆█▇█▇▇██</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">restful-sweep-15</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/0hq7d047" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/0hq7d047</a><br/>
# wandb: Agent Starting Run: savqgiaz with config:
# wandb: 	batch_size: 36
# wandb: 	dropout: 0.6
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.006929500707050407
# wandb: 	mid_layer_size: 1024
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">smart-sweep-16</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/savqgiaz" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/savqgiaz</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_212612-savqgiaz</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1970<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_212612-savqgiaz/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_212612-savqgiaz/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>1.06326</td></tr><tr><td>_runtime</td><td>149</td></tr><tr><td>_timestamp</td><td>1624483721</td></tr><tr><td>_step</td><td>569</td></tr><tr><td>loss</td><td>0.81376</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▂▂▂▄▄▅▅▃▂▄▅▄▅▃▂▂▂▁▅▄▆▂▂▄▂▄▅▂▅▄▃▃▁▃▄▆▄▁▂█</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▂▆▆▁██▃▆▃█</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">smart-sweep-16</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/savqgiaz" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/savqgiaz</a><br/>
# wandb: Agent Starting Run: uu9rf9te with config:
# wandb: 	batch_size: 229
# wandb: 	dropout: 0.4
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.038944163071434085
# wandb: 	mid_layer_size: 256
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">effortless-sweep-17</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/uu9rf9te" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/uu9rf9te</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210623_212848-uu9rf9te</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 2015<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210623_212848-uu9rf9te/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210623_212848-uu9rf9te/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.89221</td></tr><tr><td>_runtime</td><td>154</td></tr><tr><td>_timestamp</td><td>1624483882</td></tr><tr><td>_step</td><td>99</td></tr><tr><td>loss</td><td>0.81961</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▁▄▆▆▅▅▇▆▆▆▅▆▃▄▇▇▆▆▅▄▅▇▅▅▄▅▅▇▅▆▆▄▆▆▅▄█▄▅█</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁███▇█▇█▇█</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">effortless-sweep-17</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/uu9rf9te" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/uu9rf9te</a><br/>
# wandb: Agent Starting Run: 3jlhbvpv with config:
# wandb: 	batch_size: 82
# wandb: 	dropout: 0.4
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.051981150097252085
# wandb: 	mid_layer_size: 1024
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
# ...
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/63vcvh48" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/63vcvh48</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_005344-63vcvh48</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 5473<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_005344-63vcvh48/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_005344-63vcvh48/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.82203</td></tr><tr><td>_runtime</td><td>152</td></tr><tr><td>_timestamp</td><td>1624496176</td></tr><tr><td>_step</td><td>119</td></tr><tr><td>loss</td><td>0.81698</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▁▇▄▄▇▅▅▄▅▄▃▇▆▇▆▄▇▅▄▇▅▇▅▅▆▅▂█▃▅▅▅▇▄▄▇▃▅▆▆</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁▇█▇▆▇██▇▇</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">trim-sweep-95</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/63vcvh48" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/63vcvh48</a><br/>
# wandb: Agent Starting Run: bgjk18pr with config:
# wandb: 	batch_size: 45
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0412728562531485
# wandb: 	mid_layer_size: 512
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">comfy-sweep-96</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/bgjk18pr" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/bgjk18pr</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_005625-bgjk18pr</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 5518<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_005625-bgjk18pr/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_005625-bgjk18pr/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.81326</td></tr><tr><td>_runtime</td><td>150</td></tr><tr><td>_timestamp</td><td>1624496335</td></tr><tr><td>_step</td><td>459</td></tr><tr><td>loss</td><td>0.8098</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▄▁▃▄▃▄▆█▇▁▄▂▅▄▅▇▅▃▃▂▂▇▄▇▃▄▄▇▇▁▄▅▇▅▃▇▇▃▄▅</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁▅▅▅█▅▅▅▂▅</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">comfy-sweep-96</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/bgjk18pr" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/bgjk18pr</a><br/>
# wandb: Agent Starting Run: 1bn77p24 with config:
# wandb: 	batch_size: 83
# wandb: 	dropout: 0.5
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.059903712153819594
# wandb: 	mid_layer_size: 1024
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">earnest-sweep-97</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/1bn77p24" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/1bn77p24</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_005903-1bn77p24</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 5563<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_005903-1bn77p24/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_005903-1bn77p24/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.31396</td></tr><tr><td>_runtime</td><td>149</td></tr><tr><td>_timestamp</td><td>1624496492</td></tr><tr><td>_step</td><td>249</td></tr><tr><td>loss</td><td>0.32141</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>█▆▃▂▂▂▁▁▁▁▂▂▂▁▁▁▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">earnest-sweep-97</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/1bn77p24" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/1bn77p24</a><br/>
# wandb: Agent Starting Run: k9a14vym with config:
# wandb: 	batch_size: 67
# wandb: 	dropout: 0.4
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.012419327198169183
# wandb: 	mid_layer_size: 512
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">giddy-sweep-98</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/k9a14vym" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/k9a14vym</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_010141-k9a14vym</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 5608<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_010141-k9a14vym/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_010141-k9a14vym/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.34036</td></tr><tr><td>_runtime</td><td>150</td></tr><tr><td>_timestamp</td><td>1624496651</td></tr><tr><td>_step</td><td>309</td></tr><tr><td>loss</td><td>0.33064</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>██▇▆▄▃▂▂▂▂▂▂▂▁▁▂▁▂▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">giddy-sweep-98</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/k9a14vym" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/k9a14vym</a><br/>
# wandb: Agent Starting Run: v0cjm0nd with config:
# wandb: 	batch_size: 244
# wandb: 	dropout: 0.4
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0016354078721799949
# wandb: 	mid_layer_size: 512
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">stoic-sweep-99</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/v0cjm0nd" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/v0cjm0nd</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_010419-v0cjm0nd</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 5651<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_010419-v0cjm0nd/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_010419-v0cjm0nd/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.3348</td></tr><tr><td>_runtime</td><td>156</td></tr><tr><td>_timestamp</td><td>1624496815</td></tr><tr><td>_step</td><td>99</td></tr><tr><td>loss</td><td>0.32466</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>█▆▄▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">stoic-sweep-99</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/v0cjm0nd" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/v0cjm0nd</a><br/>
# wandb: Agent Starting Run: rfzvni7z with config:
# wandb: 	batch_size: 43
# wandb: 	dropout: 0.4
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.09263505188606334
# wandb: 	mid_layer_size: 256
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">sleek-sweep-100</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20</a><br/>
#                 Sweep page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/sweeps/a15hf3ib</a><br/>
# Run page: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/rfzvni7z" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/rfzvni7z</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_010702-rfzvni7z</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 5696<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_010702-rfzvni7z/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_010702-rfzvni7z/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.6466</td></tr><tr><td>_runtime</td><td>152</td></tr><tr><td>_timestamp</td><td>1624496974</td></tr><tr><td>_step</td><td>479</td></tr><tr><td>loss</td><td>0.78008</td></tr><tr><td>epoch</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▅▁▄▃▇▅▅▅▅▅▅▄▆█▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▇▇▇</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁▂▂▂▂▂▂▂▂█</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sleek-sweep-100</strong>: <a href="https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/rfzvni7z" target="_blank">https://wandb.ai/khan_m_a/pytorch_hp_tuning%20/runs/rfzvni7z</a><br/>

# %%
# check the size of batch size and format

# for images, labels in build_dataset(16,  train_labels, train_path):
#     break

# print(images.shape, [has_fire[l] for l in labels.numpy()])
